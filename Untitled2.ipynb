# %%
import pandas as pd

# Read CSV files
file2 = 'uber-raw-data-apr14.csv'
file3 = 'uber-raw-data-aug14.csv'
file5 = 'uber-raw-data-jul14.csv'
file6 = 'uber-raw-data-jun14.csv'
file7 = 'uber-raw-data-may14.csv'
file8 = 'uber-raw-data-sep14.csv'

# %%
df2 = pd.read_csv(file3)
df2
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1         8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2         8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3         8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4         8/1/2014 0:12:00  40.7323 -74.0077  B02512
# ...                    ...      ...      ...     ...
# 829270  8/31/2014 23:55:00  40.7552 -73.9753  B02764
# 829271  8/31/2014 23:55:00  40.7552 -73.9753  B02764
# 829272  8/31/2014 23:55:00  40.7617 -73.9788  B02764
# 829273  8/31/2014 23:59:00  40.7395 -73.9889  B02764
# 829274  8/31/2014 23:59:00  40.7270 -73.9802  B02764
#
# [829275 rows x 4 columns]

# %%
df3 = pd.read_csv(file3)
df3
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1         8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2         8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3         8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4         8/1/2014 0:12:00  40.7323 -74.0077  B02512
# ...                    ...      ...      ...     ...
# 829270  8/31/2014 23:55:00  40.7552 -73.9753  B02764
# 829271  8/31/2014 23:55:00  40.7552 -73.9753  B02764
# 829272  8/31/2014 23:55:00  40.7617 -73.9788  B02764
# 829273  8/31/2014 23:59:00  40.7395 -73.9889  B02764
# 829274  8/31/2014 23:59:00  40.7270 -73.9802  B02764
#
# [829275 rows x 4 columns]

# %%
df5 = pd.read_csv(file5)
df5
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         7/1/2014 0:03:00  40.7586 -73.9706  B02512
# 1         7/1/2014 0:05:00  40.7605 -73.9994  B02512
# 2         7/1/2014 0:06:00  40.7320 -73.9999  B02512
# 3         7/1/2014 0:09:00  40.7635 -73.9793  B02512
# 4         7/1/2014 0:20:00  40.7204 -74.0047  B02512
# ...                    ...      ...      ...     ...
# 796116  7/31/2014 23:22:00  40.7285 -73.9846  B02764
# 796117  7/31/2014 23:23:00  40.7615 -73.9868  B02764
# 796118  7/31/2014 23:29:00  40.6770 -73.9515  B02764
# 796119  7/31/2014 23:30:00  40.7225 -74.0038  B02764
# 796120  7/31/2014 23:58:00  40.7199 -73.9884  B02764
#
# [796121 rows x 4 columns]

# %%
df6 = pd.read_csv(file6)
df6
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         6/1/2014 0:00:00  40.7293 -73.9920  B02512
# 1         6/1/2014 0:01:00  40.7131 -74.0097  B02512
# 2         6/1/2014 0:04:00  40.3461 -74.6610  B02512
# 3         6/1/2014 0:04:00  40.7555 -73.9833  B02512
# 4         6/1/2014 0:07:00  40.6880 -74.1831  B02512
# ...                    ...      ...      ...     ...
# 663839  6/30/2014 22:40:00  40.7332 -73.9872  B02764
# 663840  6/30/2014 23:12:00  40.7905 -73.9796  B02764
# 663841  6/30/2014 23:13:00  40.7640 -73.9887  B02764
# 663842  6/30/2014 23:15:00  40.7262 -73.9944  B02764
# 663843  6/30/2014 23:35:00  40.7404 -73.9848  B02764
#
# [663844 rows x 4 columns]

# %%
df7 = pd.read_csv(file7)
df7
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         5/1/2014 0:02:00  40.7521 -73.9914  B02512
# 1         5/1/2014 0:06:00  40.6965 -73.9715  B02512
# 2         5/1/2014 0:15:00  40.7464 -73.9838  B02512
# 3         5/1/2014 0:17:00  40.7463 -74.0011  B02512
# 4         5/1/2014 0:17:00  40.7594 -73.9734  B02512
# ...                    ...      ...      ...     ...
# 652430  5/31/2014 23:45:00  40.7309 -74.0014  B02764
# 652431  5/31/2014 23:52:00  40.7528 -73.9798  B02764
# 652432  5/31/2014 23:55:00  40.7158 -73.9519  B02764
# 652433  5/31/2014 23:56:00  40.6961 -73.8997  B02764
# 652434  5/31/2014 23:59:00  40.7393 -73.9919  B02764
#
# [652435 rows x 4 columns]

# %%
df8 = pd.read_csv(file8)
df8
# Out:
#                   Date/Time      Lat      Lon    Base
# 0          9/1/2014 0:01:00  40.2201 -74.0021  B02512
# 1          9/1/2014 0:01:00  40.7500 -74.0027  B02512
# 2          9/1/2014 0:03:00  40.7559 -73.9864  B02512
# 3          9/1/2014 0:06:00  40.7450 -73.9889  B02512
# 4          9/1/2014 0:11:00  40.8145 -73.9444  B02512
# ...                     ...      ...      ...     ...
# 1028131  9/30/2014 22:57:00  40.7668 -73.9845  B02764
# 1028132  9/30/2014 22:57:00  40.6911 -74.1773  B02764
# 1028133  9/30/2014 22:58:00  40.8519 -73.9319  B02764
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764
#
# [1028136 rows x 4 columns]

# %%
# Concatenate DataFrames
combined_df = pd.concat([df2, df3, df5, df6, df7, df8], ignore_index=True)
rows_with_null = combined_df.isnull().any(axis=1).sum()
rows_with_null
# Out:
# 0

# %%
combined_df
# Out:
#                   Date/Time      Lat      Lon    Base
# 0          8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1          8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2          8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3          8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4          8/1/2014 0:12:00  40.7323 -74.0077  B02512
# ...                     ...      ...      ...     ...
# 4799081  9/30/2014 22:57:00  40.7668 -73.9845  B02764
# 4799082  9/30/2014 22:57:00  40.6911 -74.1773  B02764
# 4799083  9/30/2014 22:58:00  40.8519 -73.9319  B02764
# 4799084  9/30/2014 22:58:00  40.7081 -74.0066  B02764
# 4799085  9/30/2014 22:58:00  40.7140 -73.9496  B02764
#
# [4799086 rows x 4 columns]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8)  # Specify the number of clusters
combined_df['cluster'] = kmeans.fit_predict(combined_df[['Lat', 'Lon']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
# Plot the clustered data
plt.scatter(combined_df['Lon'], combined_df['Lat'], c=combined_df['cluster'], cmap='viridis', marker='o')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Clusters of Latitude and Longitude Coordinates')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
for index, row in combined_df.iterrows():
  time = str(row['Date/Time']).split(" ")[1]
  combined_df.at[index, 'time_index'] = time.split(":")[0]
combined_df
# Out:
#                   Date/Time      Lat      Lon    Base  cluster time_index
# 0          8/1/2014 0:03:00  40.7366 -73.9906  B02512        7          0
# 1          8/1/2014 0:09:00  40.7260 -73.9918  B02512        7          0
# 2          8/1/2014 0:12:00  40.7209 -74.0507  B02512        7          0
# 3          8/1/2014 0:12:00  40.7387 -73.9856  B02512        7          0
# 4          8/1/2014 0:12:00  40.7323 -74.0077  B02512        7          0
# ...                     ...      ...      ...     ...      ...        ...
# 4799081  9/30/2014 22:57:00  40.7668 -73.9845  B02764        0         22
# 4799082  9/30/2014 22:57:00  40.6911 -74.1773  B02764        3         22
# 4799083  9/30/2014 22:58:00  40.8519 -73.9319  B02764        6         22
# 4799084  9/30/2014 22:58:00  40.7081 -74.0066  B02764        7         22
# 4799085  9/30/2014 22:58:00  40.7140 -73.9496  B02764        4         22
#
# [4799086 rows x 6 columns]

# %%
combined_df = combined_df.sort_values(by='Date/Time')
combined_df
# Out:
#                 Date/Time      Lat      Lon    Base  cluster time_index
# 3538563  5/1/2014 0:00:00  40.7224 -73.9917  B02682        7          0
# 3155282  5/1/2014 0:00:00  40.6449 -73.7822  B02598        1          0
# 3155281  5/1/2014 0:00:00  40.7065 -74.0061  B02598        7          0
# 3155280  5/1/2014 0:00:00  40.7600 -73.9761  B02598        0          0
# 3155287  5/1/2014 0:01:00  40.7311 -73.9888  B02598        7          0
# ...                   ...      ...      ...     ...      ...        ...
# 4152317  9/9/2014 9:59:00  40.7134 -73.9404  B02617        4          9
# 4152316  9/9/2014 9:59:00  40.7920 -73.9676  B02617        0          9
# 4152315  9/9/2014 9:59:00  40.6745 -73.9817  B02617        4          9
# 4655469  9/9/2014 9:59:00  40.7183 -73.9539  B02764        4          9
# 4478040  9/9/2014 9:59:00  40.7294 -73.9877  B02682        7          9
#
# [4799086 rows x 6 columns]

# %%
cluster_counts = combined_df['cluster'].value_counts()
max_cluster_num = cluster_counts.idxmax()

max_cluster_df = combined_df[combined_df['cluster'] == max_cluster_num]

time_counts = max_cluster_df['time_index'].value_counts()
top_5_time_indexes = time_counts.head(5)
print("Cluster zone is: ", max_cluster_num)
print('\n')
print("Top 5 hours that are peak are: \n", top_5_time_indexes)
# Out:
# Cluster zone is:  7
#
#
# Top 5 hours that are peak are:
#  17    146171
# 18    140605
# 16    133117
# 19    128713
# 21    128579
# Name: time_index, dtype: int64
